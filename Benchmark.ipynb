# %%
# !nvidia-smi
# Out:
# Wed Feb 28 17:34:27 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1060 6GB    Off |   00000000:01:00.0  On |                  N/A |
# |  0%   59C    P2             35W /  120W |     284MiB /   6144MiB |      9%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
model.export(format='engine', device=0)
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.8.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6066MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 0.7s, saved as 'yolov8n.onnx' (12.2 MB)
#
# TensorRT: starting export with TensorRT 8.6.1...
# [02/28/2024-17:54:25] [TRT] [I] The logger passed into createInferBuilder differs from one already provided for an existing builder, runtime, or refitter. Uses of the global logger, returned by nvinfer1::getLogger(), will return the existing value.
# [02/28/2024-17:54:25] [TRT] [I] [MemUsageChange] Init CUDA: CPU +0, GPU +0, now: CPU 3058, GPU 676 (MiB)
# [02/28/2024-17:54:30] [TRT] [I] [MemUsageChange] Init builder kernel library: CPU +231, GPU +36, now: CPU 3289, GPU 712 (MiB)
# ...

# %%
model = YOLO('yolov8n.engine', task='detect')
results = model.predict('Downloads/15 minutes of heavy traffic noise in India 14-08-2022 (online-video-cutter.com).mp4', save=True)
# Out:
# Loading yolov8n.engine for TensorRT inference...
# [02/28/2024-17:47:04] [TRT] [I] Loaded engine size: 19 MiB
# [02/28/2024-17:47:04] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in engine deserialization: CPU +0, GPU +19, now: CPU 0, GPU 19 (MiB)
# [02/28/2024-17:47:04] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +21, now: CPU 0, GPU 40 (MiB)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# ...

# %%
model = YOLO('yolov8n.pt')
results = model.predict('Downloads/15 minutes of heavy traffic noise in India 14-08-2022 (online-video-cutter.com).mp4', save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/910) /home/guilhermezat/Downloads/15 minutes of heavy traffic noise in India 14-08-2022 (online-video-cutter.com).mp4: 384x640 2 persons, 15 cars, 4 motorcycles, 4 buss, 5 trucks, 153.1ms
# video 1/1 (2/910) /home/guilhermezat/Downloads/15 minutes of heavy traffic noise in India 14-08-2022 (online-video-cutter.com).mp4: 384x640 2 persons, 14 cars, 4 motorcycles, 4 buss, 6 trucks, 9.3ms
# ...

# %%
model = YOLO('yolov8n.pt')
results = model.predict('Downloads/15 minutes of heavy traffic noise in India 14-08-2022 (online-video-cutter.com).mp4', save=True, device='cpu')
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/910) /home/guilhermezat/Downloads/15 minutes of heavy traffic noise in India 14-08-2022 (online-video-cutter.com).mp4: 384x640 2 persons, 15 cars, 4 motorcycles, 4 buss, 5 trucks, 127.6ms
# video 1/1 (2/910) /home/guilhermezat/Downloads/15 minutes of heavy traffic noise in India 14-08-2022 (online-video-cutter.com).mp4: 384x640 2 persons, 14 cars, 4 motorcycles, 4 buss, 6 trucks, 73.7ms
# ...
